# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/shooting/curry-2009-2019/curry-2010.csv')
df.head(11)

# df.groupby('vs').count()
# Out:
#           date  home   vs  quarter time_left  shot_made  shot_value  \
# 0   2009-10-28  True  HOU        1     11:25      False           3
# 1   2009-10-28  True  HOU        1     09:31       True           2
# 2   2009-10-28  True  HOU        1     06:02      False           2
# 3   2009-10-28  True  HOU        2     09:49      False           2
# 4   2009-10-28  True  HOU        2     02:19      False           2
# 5   2009-10-28  True  HOU        2     00:34      False           2
# 6   2009-10-28  True  HOU        4     10:26       True           2
# 7   2009-10-28  True  HOU        4     06:31       True           2
# 8   2009-10-28  True  HOU        4     02:25       True           2
# 9   2009-10-28  True  HOU        4     01:47       True           2
# 10  2009-10-28  True  HOU        4     00:29       True           2
#
#     shot_distance    x    y             shot_description  \
# 0              27  339  299  Missed 3-pointer from 27 ft
# ...

# %%
plt.scatter(df['x'],df['y'], alpha=0.5)

# %%
df3 = pd.read_csv('../data/shooting/curry-2009-2019/curry-2015.csv')
df3
# Out:
#             date   home   vs  quarter time_left  shot_made  shot_value  \
# 0     2014-10-29  False  SAC        1     07:29       True           2
# 1     2014-10-29  False  SAC        1     05:09      False           3
# 2     2014-10-29  False  SAC        2     08:49       True           2
# 3     2014-10-29  False  SAC        2     06:43       True           2
# 4     2014-10-29  False  SAC        2     05:36      False           3
# ...          ...    ...  ...      ...       ...        ...         ...
# 1762  2015-06-16  False  CLE        4     07:26       True           3
# 1763  2015-06-16  False  CLE        4     04:33      False           3
# 1764  2015-06-16  False  CLE        4     03:31      False           2
# 1765  2015-06-16  False  CLE        4     01:54       True           2
# 1766  2015-06-16  False  CLE        4     01:20      False           3
#
#       shot_distance    x    y             shot_description  \
# ...

# %%
plt.scatter(df3['x'], df3['y'], alpha=0.5)

# %%
df2 = pd.read_csv('../data/shooting/curry-2009-2019/curry-2019.csv')
df2
# Out:
#             date  home   vs  quarter time_left  shot_made  shot_value  \
# 0     2018-10-16  True  OKC        1     11:31       True           3
# 1     2018-10-16  True  OKC        1     07:57       True           2
# 2     2018-10-16  True  OKC        1     03:46       True           2
# 3     2018-10-16  True  OKC        1     02:58      False           2
# 4     2018-10-16  True  OKC        1     02:49       True           3
# ...          ...   ...  ...      ...       ...        ...         ...
# 1745  2019-06-13  True  TOR        4     07:30      False           2
# 1746  2019-06-13  True  TOR        4     06:00       True           2
# 1747  2019-06-13  True  TOR        4     05:32      False           3
# 1748  2019-06-13  True  TOR        4     04:03      False           3
# 1749  2019-06-13  True  TOR        4     00:08      False           3
#
#       shot_distance    x    y             shot_description  \
# 0                24  466  143    Made 3-pointer from 24 ft
# ...

# %%
plt.scatter(df2['x'], df2['y'], alpha=0.5)
