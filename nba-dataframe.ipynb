# %%
from nba_api.stats.static import players,teams
from nba_api.stats.endpoints import PlayerVsPlayer, TeamVsPlayer, leaguegamefinder, playbyplay,CommonAllPlayers, CommonPlayerInfo
import pandas as pd 
import numpy as np
import json
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

# %%
def filter_col_team(df):
    return df.drop(['Overall','vsPlayerOverall','ShotDistanceOverall','ShotDistanceOffCourt','ShotAreaOverall','ShotAreaOffCourt'],axis=1)

# %%
def filter_col_player(df):
    return df.drop(['Overall','ShotDistanceOverall','ShotDistanceOffCourt','ShotAreaOverall','ShotAreaOffCourt'],axis=1)

# %%
def season_team(season,player_id,nba_team_info):
    new_df = pd.DataFrame(columns=nba_team_info['full_name'],index = [season])
    for (i,j) in zip(nba_team_info['full_name'],nba_team_info['id']):
        dict_team = TeamVsPlayer(team_id=j,season=season,vs_player_id=player_id, headers=headers).get_normalized_dict()
        dict_to_df = pd.DataFrame.from_dict(dict_team, orient = 'index').transpose()
        filtered_col = filter_col_team(dict_to_df)
        new_df.loc[season][i] = filtered_col
    return new_df

# %%
def season_player(season,player_id,nba_player_info):
    new_df = pd.DataFrame(columns=nba_player_info['full_name'], index = [season])
    for (i,j) in zip(nba_player_info['full_name'],nba_player_info['id']):
        dict_team = PlayerVsPlayer(player_id=player_id,vs_player_id=j,season=season, headers=headers).get_normalized_dict()
        dict_to_df = pd.DataFrame.from_dict(dict_team, orient = 'index').transpose()
        filtered_col = filter_col_player(dict_to_df)
        new_df.loc[season][i] = filtered_col
    return new_df

# %%
    headers = {
    'Host': 'stats.nba.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:61.0) Gecko/20100101 Firefox/61.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    }

# %%
    #All NBA Players Information in DataFrame
    nba_players_info = pd.concat([pd.DataFrame.from_dict(players.get_players()[i], orient='index').transpose() for i in range(len(players.get_players()))],ignore_index=True)
    
    #All NBA Teams Information in DataFrame
    nba_teams_info = pd.concat([pd.DataFrame.from_dict(teams.get_teams()[i], orient='index').transpose() for i in range(30)],ignore_index=True)
    
    #Players that are active right now
    players_active = nba_players_info[nba_players_info['is_active'] == True].reset_index(drop=True)
    
    #Players Active in Array
    players_active_array = players_active['full_name'].values
    
    #Teams in Array 
    teams_array = nba_teams_info['full_name'].values
    
    #Seasons in Array
    seasons = ['2018-19','2017-18','2016-17','2015-16','2014-15','2013-14','2012-13','2011-12','2010-11','2009-10']
    
    #Stephs ID
    steph_id = players.find_players_by_full_name('Steph')[1]['id']

# %% [markdown]
# # PLAYER VS TEAMS

# %%
season_2018_19 = season_team("2018-19",steph_id,nba_teams_info)

# %%
season_2017_18 = season_team("2017-18",steph_id,nba_teams_info)

# %%
season_2016_17 = season_team("2016-17",steph_id,nba_teams_info)

# %%
season_2015_16 = season_team("2015-16",steph_id,nba_teams_info)

# %%
season_2014_15 = season_team("2014-15",steph_id,nba_teams_info)

# %%
season_2013_14 = season_team("2013-14",steph_id,nba_teams_info)

# %%
season_2012_13 = season_team("2012-13",steph_id,nba_teams_info)

# %%
season_2011_12 = season_team("2011-12",steph_id,nba_teams_info)

# %%
season_2010_11 = season_team("2010-11",steph_id,nba_teams_info)

# %%
season_2009_10 = season_team("2009-10",steph_id,nba_teams_info)

# %%
StephVsTeam_df = pd.concat([season_2018_19,season_2017_18,season_2016_17,season_2015_16,season_2014_15,season_2013_14,season_2012_13,season_2011_12,season_2010_11,season_2009_10],axis=0)

# %% [markdown]
# # PLAYER VS PLAYER MATCHUP

# %%
p_season_2018_19 = season_player("2018-19",steph_id,players_active)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# /anaconda3/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# /anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
# --> 310                 raise timeout('The read operation timed out')
#     311             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 386             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     387             raise
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     305         if isinstance(err, SocketTimeout):
# --> 306             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     307
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-31-ebd368ae2de6> in <module>
# ----> 1 p_season_2018_19 = season_player("2018-19",steph_id,players_active)
#
# <ipython-input-5-3e6fb0526ff2> in season_player(season, player_id, nba_player_info)
#       2     new_df = pd.DataFrame(columns=nba_player_info['full_name'], index = [season])
#       3     for (i,j) in zip(nba_player_info['full_name'],nba_player_info['id']):
# ----> 4         dict_team = PlayerVsPlayer(player_id=player_id,vs_player_id=j,season=season, headers=headers).get_normalized_dict()
#       5         dict_to_df = pd.DataFrame.from_dict(dict_team, orient = 'index').transpose()
#       6         filtered_col = filter_col_player(dict_to_df)
#
# /anaconda3/lib/python3.7/site-packages/nba_api/stats/endpoints/playervsplayer.py in __init__(self, vs_player_id, player_id, last_n_games, measure_type_detailed_defense, month, opponent_team_id, pace_adjust, per_mode_detailed, period, plus_minus, rank, season, season_type_playoffs, date_from_nullable, date_to_nullable, game_segment_nullable, league_id_nullable, location_nullable, outcome_nullable, season_segment_nullable, vs_conference_nullable, vs_division_nullable, proxy, headers, timeout, get_request)
#      70         }
#      71         if get_request:
# ---> 72             self.get_request()
#      73
#      74     def get_request(self):
#
# /anaconda3/lib/python3.7/site-packages/nba_api/stats/endpoints/playervsplayer.py in get_request(self)
#      78             proxy=self.proxy,
#      79             headers=self.headers,
# ---> 80             timeout=self.timeout,
#      81         )
#      82         self.load_response()
#
# /anaconda3/lib/python3.7/site-packages/nba_api/library/http.py in send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     121
#     122         if not contents:
# --> 123             response = requests.get(url=base_url, params=parameters, headers=request_headers, proxies=proxies, timeout=timeout)
#     124             url = response.url
#     125             status_code = response.status_code
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
p_season_2017_18 = season_player("2017-18",steph_id,players_active)

# %%
p_season_2016_17 = season_player("2016-17",steph_id,players_active)

# %%
p_season_2015_16 = season_player("2015-16",steph_id,players_active)

# %%
p_season_2014_15 = season_player("2014-15",steph_id,players_active)

# %%
p_season_2013_14 = season_player("2013-14",steph_id,players_active)

# %%
p_season_2012_13 = season_player("2012-13",steph_id,players_active)

# %%
p_season_2011_12 = season_player("2011-12",steph_id,players_active)

# %%
p_season_2010_11 = season_player("2010-11",steph_id,players_active)

# %%
p_season_2009_10 = season_player("2009-10",steph_id,players_active)

# %%
p_season_2017
# Out:
# full_name                                      Atlanta Hawks  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                     Boston Celtics  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                Cleveland Cavaliers  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                               New Orleans Pelicans  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                      Chicago Bulls  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                   Dallas Mavericks  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                     Denver Nuggets  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                              Golden State Warriors  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                    Houston Rockets  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                               Los Angeles Clippers  ...  \
# 2018-19                                              OnOf...  ...
# 2017-18                                              OnOf...  ...
# 2016-17                                              OnOf...  ...
# 2015-16                                              OnOf...  ...
# 2014-15                                              OnOf...  ...
# 2013-14                                              OnOf...  ...
# 2012-13                                              OnOf...  ...
# 2011-12                                              OnOf...  ...
# 2010-11                                              OnOf...  ...
# 2009-10                                              OnOf...  ...
#
# full_name                             Portland Trail Blazers  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                   Sacramento Kings  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                  San Antonio Spurs  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                              Oklahoma City Thunder  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                    Toronto Raptors  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                          Utah Jazz  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                  Memphis Grizzlies  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                 Washington Wizards  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                    Detroit Pistons  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                  Charlotte Hornets
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# [10 rows x 30 columns]

# %%
players_active
# Out:
#           id               full_name first_name      last_name is_active
# 0     203518            Alex Abrines       Alex        Abrines      True
# 1     203112              Quincy Acy     Quincy            Acy      True
# 2    1629121            Jaylen Adams     Jaylen          Adams      True
# 3     203500            Steven Adams     Steven          Adams      True
# 4    1628389             Bam Adebayo        Bam        Adebayo      True
# 5    1629061               Deng Adel       Deng           Adel      True
# 6    1629152  DeVaughn Akoon-Purcell   DeVaughn  Akoon-Purcell      True
# 7     200746       LaMarcus Aldridge   LaMarcus       Aldridge      True
# 8    1628959            Rawle Alkins      Rawle         Alkins      True
# 9    1628960           Grayson Allen    Grayson          Allen      True
# 10   1628386           Jarrett Allen    Jarrett          Allen      True
# 11   1628443            Kadeem Allen     Kadeem          Allen      True
# 12    202329         Al-Farouq Aminu  Al-Farouq          Aminu      True
# 13   1626147         Justin Anderson     Justin       Anderson      True
# 14    203937           Kyle Anderson       Kyle       Anderson      True
# 15    201583           Ryan Anderson       Ryan       Anderson      True
# 16   1628387            Ike Anigbogu        Ike       Anigbogu      True
# 17    203507   Giannis Antetokounmpo    Giannis  Antetokounmpo      True
# 18   1628961    Kostas Antetokounmpo     Kostas  Antetokounmpo      True
# 19      2546         Carmelo Anthony    Carmelo        Anthony      True
# 20   1628384              OG Anunoby         OG        Anunoby      True
# 21   1627853        Ryan Arcidiacono       Ryan    Arcidiacono      True
# 22      2772            Trevor Ariza     Trevor          Ariza      True
# 23    201571           D.J. Augustin       D.J.       Augustin      True
# 24   1629028           Deandre Ayton    Deandre          Ayton      True
# 25   1628407            Dwayne Bacon     Dwayne          Bacon      True
# 26   1628963       Marvin Bagley III     Marvin     Bagley III      True
# 27   1627758               Ron Baker        Ron          Baker      True
# 28   1627735         Wade Baldwin IV       Wade     Baldwin IV      True
# 29   1628366              Lonzo Ball      Lonzo           Ball      True
# ..       ...                     ...        ...            ...       ...
# 516  1627395         Julian Washburn     Julian       Washburn      True
# 517  1629139           Yuta Watanabe       Yuta       Watanabe      True
# 518  1629118            Thomas Welsh     Thomas          Welsh      True
# 519   201566       Russell Westbrook    Russell      Westbrook      True
# 520  1628401           Derrick White    Derrick          White      True
# 521  1627855             Okaro White      Okaro          White      True
# 522  1627785        Isaiah Whitehead     Isaiah      Whitehead      True
# 523   202355        Hassan Whiteside     Hassan      Whiteside      True
# 524   203952          Andrew Wiggins     Andrew        Wiggins      True
# 525  1626210           Alan Williams       Alan       Williams      True
# 526   203710           C.J. Williams       C.J.       Williams      True
# 527  1629140      Johnathan Williams  Johnathan       Williams      True
# 528  1629026        Kenrich Williams    Kenrich       Williams      True
# 529   101150            Lou Williams        Lou       Williams      True
# 530   101107         Marvin Williams     Marvin       Williams      True
# 531  1627786           Troy Williams       Troy       Williams      True
# 532  1629057     Robert Williams III     Robert   Williams III      True
# 533  1628391             D.J. Wilson       D.J.         Wilson      True
# 534  1626159         Justise Winslow    Justise        Winslow      True
# 535  1626174          Christian Wood  Christian           Wood      True
# 536  1626153            Delon Wright      Delon         Wright      True
# 537  1627824      Guerschon Yabusele  Guerschon       Yabusele      True
# 538   201156              Nick Young       Nick          Young      True
# 539   201152          Thaddeus Young   Thaddeus          Young      True
# 540  1629027              Trae Young       Trae          Young      True
# 541   203469             Cody Zeller       Cody         Zeller      True
# 542   203092            Tyler Zeller      Tyler         Zeller      True
# 543  1627753                 Zhou Qi                   Zhou Qi      True
# 544  1627790              Ante Zizic       Ante          Zizic      True
# 545  1627826             Ivica Zubac      Ivica          Zubac      True
#
# [546 rows x 5 columns]

# %%
StephVsTeam_df.to_csv('steph-vs-team.csv')

# %%
test = StephVsTeam_df.loc['2018-19']['Atlanta Hawks']

# %%
test
# Out:
#                                           OnOffCourt  \
# 0  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 1  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
#
#                                  ShotDistanceOnCourt  \
# 0  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 1  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 2  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 3  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 4  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 5  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 6  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 7  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 8  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
#
#                                      ShotAreaOnCourt
# 0  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 1  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 2  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 3  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 4  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 5  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 6  {'GROUP_SET': 'Vs. Player', 'TEAM_ID': 1610612...
# 7                                               None
# 8                                               None

# %%
test.loc[0]['OnOffCourt']
# Out:
# {'GROUP_SET': 'Vs. Player',
#  'TEAM_ID': 1610612737,
#  'TEAM_ABBREVIATION': 'ATL',
#  'TEAM_NAME': 'Atlanta Hawks',
#  'VS_PLAYER_ID': 201939,
#  'VS_PLAYER_NAME': 'Curry, Stephen',
#  'COURT_STATUS': 'On',
#  'GP': 1,
#  'W': 0,
#  'L': 1,
#  'W_PCT': 0.0,
#  'MIN': 29.108333333333334,
#  'FGM': 25,
#  'FGA': 49,
#  'FG_PCT': 0.51,
#  'FG3M': 4,
#  'FG3A': 14,
#  'FG3_PCT': 0.286,
#  'FTM': 4,
#  'FTA': 6,
#  'FT_PCT': 0.667,
#  'OREB': 3,
#  'DREB': 16,
#  'REB': 19,
#  'AST': 11,
#  'TOV': 16.0,
#  'STL': 5,
#  'BLK': 2,
#  'BLKA': 6,
#  'PF': 16,
#  'PFD': 10,
#  'PTS': 58,
#  'PLUS_MINUS': -22.0,
#  'GP_RANK': 2,
#  'W_RANK': 1,
#  'L_RANK': 1,
#  'W_PCT_RANK': 1,
#  'MIN_RANK': 2,
#  'FGM_RANK': 2,
#  'FGA_RANK': 2,
#  'FG_PCT_RANK': 1,
#  'FG3M_RANK': 2,
#  'FG3A_RANK': 2,
#  'FG3_PCT_RANK': 2,
#  'FTM_RANK': 2,
#  'FTA_RANK': 2,
#  'FT_PCT_RANK': 2,
#  'OREB_RANK': 2,
#  'DREB_RANK': 2,
#  'REB_RANK': 2,
#  'AST_RANK': 2,
#  'TOV_RANK': 1,
#  'STL_RANK': 2,
#  'BLK_RANK': 2,
#  'BLKA_RANK': 1,
#  'PF_RANK': 1,
#  'PFD_RANK': 2,
#  'PTS_RANK': 2,
#  'PLUS_MINUS_RANK': 2,
#  'CFID': 214,
#  'CFPARAMS': '201939'}

# %%
test.loc[2]['ShotDistanceOnCourt']
# Out:
# {'GROUP_SET': 'Vs. Player',
#  'TEAM_ID': 1610612737,
#  'TEAM_ABBREVIATION': 'ATL',
#  'TEAM_NAME': 'Atlanta Hawks',
#  'VS_PLAYER_ID': 201939,
#  'VS_PLAYER_NAME': 'Curry, Stephen',
#  'COURT_STATUS': 'On',
#  'GROUP_VALUE': '10-14 ft.',
#  'FGM': 4,
#  'FGA': 4,
#  'FG_PCT': 1.0,
#  'CFID': 248,
#  'CFPARAMS': '201939'}

# %%
StephVsTeam_df
# Out:
# full_name                                      Atlanta Hawks  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                     Boston Celtics  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                Cleveland Cavaliers  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                               New Orleans Pelicans  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                      Chicago Bulls  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                   Dallas Mavericks  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                     Denver Nuggets  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                              Golden State Warriors  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                    Houston Rockets  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                               Los Angeles Clippers  ...  \
# 2018-19                                              OnOf...  ...
# 2017-18                                              OnOf...  ...
# 2016-17                                              OnOf...  ...
# 2015-16                                              OnOf...  ...
# 2014-15                                              OnOf...  ...
# 2013-14                                              OnOf...  ...
# 2012-13                                              OnOf...  ...
# 2011-12                                              OnOf...  ...
# 2010-11                                              OnOf...  ...
# 2009-10                                              OnOf...  ...
#
# full_name                             Portland Trail Blazers  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                   Sacramento Kings  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                  San Antonio Spurs  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                              Oklahoma City Thunder  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                    Toronto Raptors  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                          Utah Jazz  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                  Memphis Grizzlies  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                 Washington Wizards  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                    Detroit Pistons  \
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# full_name                                  Charlotte Hornets
# 2018-19                                              OnOf...
# 2017-18                                              OnOf...
# 2016-17                                              OnOf...
# 2015-16                                              OnOf...
# 2014-15                                              OnOf...
# 2013-14                                              OnOf...
# 2012-13                                              OnOf...
# 2011-12                                              OnOf...
# 2010-11                                              OnOf...
# 2009-10                                              OnOf...
#
# [10 rows x 30 columns]
