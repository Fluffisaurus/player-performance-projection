# %%
import pandas as pd

# %%
df = pd.read_csv('steph-vs-team.csv')
df
# Out:
#   Unnamed: 0                                      Atlanta Hawks  \
# 0    2018-19                                            OnOf...
# 1    2017-18                                            OnOf...
# 2    2016-17                                            OnOf...
# 3    2015-16                                            OnOf...
# 4    2014-15                                            OnOf...
# 5    2013-14                                            OnOf...
# 6    2012-13                                            OnOf...
# 7    2011-12                                            OnOf...
# 8    2010-11                                            OnOf...
# 9    2009-10                                            OnOf...
#
#                                       Boston Celtics  \
# 0                                            OnOf...
# 1                                            OnOf...
# 2                                            OnOf...
# ...
