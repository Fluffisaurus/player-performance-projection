# %%
import numpy as np
import pandas as pd

# %%
steph_ass = pd.read_csv('pbpstats_export_steph_ass.csv')

# %%
steph_ass_filter = steph_ass[['Date','Opponent','Minutes','Assists','AssistPoints','2ptAssists','3ptAssists']]

# %%
steph_board = pd.read_csv('pbpstats_export_steph_rebs.csv')

# %%
steph_board_filter = steph_board[['']]
# Out:
#            Date Team Opponent Minutes  Rebounds  DefRebounds  FTDefRebounds  \
# 0    2014-03-02  GSW      TOR   43:12         4            3              0
# 1    2014-02-28  GSW      NYK   30:18        11            9              0
# 2    2014-02-26  GSW      CHI   28:19         3            3              0
# 3    2014-02-24  GSW      DET   35:44         8            5              0
# 4    2014-02-22  GSW      BKN   31:58         5            5              0
# 5    2014-02-20  GSW      HOU   38:27         2            2              0
# 6    2014-02-19  GSW      SAC   35:51         1            1              0
# 7    2014-02-12  GSW      MIA   39:13         5            4              1
# 8    2014-02-10  GSW      PHI   27:18         5            3              0
# 9    2014-02-08  GSW      PHX   41:10         2            1              0
# 10   2014-02-06  GSW      CHI   42:46         3            3              0
# ...
